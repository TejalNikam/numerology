# %%
def numerology(full_name,numerology_number):
    number = numerology_number
    dict = { 1: { "positive": "Natural leader, confident, ambitious, independent thinker.",
                 "negative": "Can be egoistic, impatient, dominating." },
             2: { "positive": "Diplomatic, cooperative, emotional intelligence strong.",
                  "negative": "Over-sensitive, dependent, indecisive." },
             3: { "positive": "Creative, expressive, social, optimistic.",
                  "negative": "Scattered focus, dramatic, inconsistent." },
             4: { "positive": "Practical, disciplined, hardworking, loyal.",
                 "negative": "Rigid, stubborn, resistant to change." },
             5: { "positive": "Adventurous, energetic, loves freedom, adaptable.",
                  "negative": "Restless, impulsive, lacks consistency." },
             6: { "positive": "Responsible, caring, family-oriented, balanced.",
                  "negative": "Overprotective, controlling, self-sacrificing." },
             7: { "positive": "Analytical, spiritual, intelligent, deep thinker.",
                  "negative": "Overthinking, isolated, emotionally distant." },
             8: { "positive": "Ambitious, business-minded, powerful personality.",
                  "negative": "Materialistic, workaholic, aggressive." },
             9: { "positive": "Compassionate, humanitarian, generous, wise.",
                  "negative": "Emotionally intense, moody, unrealistic." } }

    print (f"Hello {full_name}\nYour Numerology number = {number} \n---> Positive: {dict[number]["positive"]}\n---> Negative: {dict[number]["negative"]} ")

def validate_name(full_name):
  name = full_name
  if not (name.isalpha() or name ==" ") :
    return
  else:
    print("Please enter your name correctly!!")
    calculate_numerology_number()


def validate_date(date_of_birth):
  date = date_of_birth
  print(date_of_birth)
  if (len(date)==10):
    return

def calculate_numerology_number():
  full_name= input("Enter your full name : ")
  validate_name(full_name)
  date_of_birth = input("Enter your date of birth in format DD MM YYYY : ")
  validate_date(date_of_birth)
  total =0
  numerology_number = 0
  for char in date_of_birth:
    if char.isdigit():
      total = total + int(char)
    else:
      pass
  num = total
  if num>9 :
    while num>0:
      a = num%10
      numerology_number = numerology_number +a
      num = num//10
    if 0<numerology_number<10:
      numerology(full_name,numerology_number)
    else:
      num=numerology_number
      numerology_number=0
      while num>0:
        a = num%10
        numerology_number = numerology_number +a
        num = num//10
      numerology(full_name,numerology_number)
  else:
      numerology(full_name,numerology_number)

# %%
print("Welcome to Numerology Personality App ")
print("------------------------------------------------------------------------------------------------------------------")
ch = 0
while True:
  calculate_numerology_number()
  ch = input("Do you want to check again y/n :")
  if ch=="y":
    print("------------------------------------------------------------------------------------------------------------------")
    continue
  else:
    break
print("------------------------------------------------------------------------------------------------------------------")
# Out:
# Welcome to Numerology Personality App
# ------------------------------------------------------------------------------------------------------------------
# Enter your full name : Tejal Nikam
# Enter your date of birth in format DD MM YYYY : 05 08 1998
# 05 08 1998
# Hello Tejal Nikam
# Your Numerology number = 4
# ---> Positive: Practical, disciplined, hardworking, loyal.
# ---> Negative: Rigid, stubborn, resistant to change.
# Do you want to check again y/n :y
# ------------------------------------------------------------------------------------------------------------------
# Enter your full name : e y
# Enter your date of birth in format DD MM YYYY : 12 34 5678
# 12 34 5678
# Hello e y
# Your Numerology number = 9
# ---> Positive: Compassionate, humanitarian, generous, wise.
# ---> Negative: Emotionally intense, moody, unrealistic.
# Do you want to check again y/n :y
# ------------------------------------------------------------------------------------------------------------------
# Enter your full name : d j
# Enter your date of birth in format DD MM YYYY : 123 45 6789
# 123 45 6789
# Hello d j
# Your Numerology number = 9
# ---> Positive: Compassionate, humanitarian, generous, wise.
# ---> Negative: Emotionally intense, moody, unrealistic.
# Do you want to check again y/n :n
# ------------------------------------------------------------------------------------------------------------------
